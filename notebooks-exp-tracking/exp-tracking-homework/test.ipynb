# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"
client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
from mlflow.entities import ViewType

HPO_EXPERIMENT_NAME ="random-forest-best-models"
experiment = client.get_experiment_by_name(HPO_EXPERIMENT_NAME)
runs = client.search_runs(
        experiment_ids=experiment.experiment_id,
        run_view_type=ViewType.ACTIVE_ONLY,
        max_results=5,
        order_by=["metrics.rmse ASC"]
    )

# %%
runs
# Out:
# [<Run: data=<RunData: metrics={'test_rmse': 2.2913864757421787,
#   'training_mean_absolute_error': 1.4208732651603648,
#   'training_mean_squared_error': 3.8865885851691204,
#   'training_r2_score': 0.27166704840687694,
#   'training_root_mean_squared_error': 1.9714432746516244,
#   'training_score': 0.27166704840687694,
#   'val_rmse': 2.455971238567075}, params={'bootstrap': 'True',
#   'ccp_alpha': '0.0',
#   'criterion': 'squared_error',
#   'max_depth': '19',
#   'max_features': '1.0',
#   'max_leaf_nodes': 'None',
#   'max_samples': 'None',
#   'min_impurity_decrease': '0.0',
#   'min_samples_leaf': '4',
#   'min_samples_split': '10',
#   'min_weight_fraction_leaf': '0.0',
#   'n_estimators': '12',
#   'n_jobs': '-1',
#   'oob_score': 'False',
#   'random_state': '42',
#   'verbose': '0',
#   'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#   'estimator_name': 'RandomForestRegressor',
#   'mlflow.log-model.history': '[{"run_id": "372919df12db44a3a6f9612f9f2d96b6", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2023-06-01 22:50:38.475710", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"predict_fn": "predict", "loader_module": '
#                               '"mlflow.sklearn", "python_version": "3.9.16", '
#                               '"env": {"conda": "conda.yaml", "virtualenv": '
#                               '"python_env.yaml"}}, "sklearn": '
#                               '{"pickled_model": "model.pkl", '
#                               '"sklearn_version": "1.2.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"6f9a8db453604eb09f79450f4d2cfd3f", '
#                               '"mlflow_version": "2.3.2", "signature": '
#                               '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                               '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                               '\\"shape\\": [-1, 6683]}}]", "outputs": '
#                               '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                               '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                               '[-1]}}]"}}]',
#   'mlflow.runName': 'victorious-whale-302',
#   'mlflow.source.git.commit': '981ccd4d024939198feffba2d5045fa595985d43',
#   'mlflow.source.name': 'register_model.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'mikygetyos'}>, info=<RunInfo: artifact_uri='/home/mikygetyos/Documents/My_Projects/NYC-Taxi-Duration/notebooks-exp-tracking/exp-tracking-homework/artifacts/2/372919df12db44a3a6f9612f9f2d96b6/artifacts', end_time=1685659840869, experiment_id='2', lifecycle_stage='active', run_id='372919df12db44a3a6f9612f9f2d96b6', run_name='victorious-whale-302', run_uuid='372919df12db44a3a6f9612f9f2d96b6', start_time=1685659836848, status='FINISHED', user_id='mikygetyos'>>,
#  <Run: data=<RunData: metrics={'test_rmse': 2.2989550579001428,
#   'training_mean_absolute_error': 1.4710628699258734,
#   'training_mean_squared_error': 3.977942629113193,
#   'training_r2_score': 0.25454762374751105,
#   'training_root_mean_squared_error': 1.9944780342518673,
#   'training_score': 0.25454762374751105,
#   'val_rmse': 2.453877262701052}, params={'bootstrap': 'True',
#   'ccp_alpha': '0.0',
#   'criterion': 'squared_error',
#   'max_depth': '11',
#   'max_features': '1.0',
#   'max_leaf_nodes': 'None',
#   'max_samples': 'None',
#   'min_impurity_decrease': '0.0',
#   'min_samples_leaf': '2',
#   'min_samples_split': '5',
#   'min_weight_fraction_leaf': '0.0',
#   'n_estimators': '22',
#   'n_jobs': '-1',
#   'oob_score': 'False',
#   'random_state': '42',
#   'verbose': '0',
#   'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#   'estimator_name': 'RandomForestRegressor',
#   'mlflow.log-model.history': '[{"run_id": "918322b23a7d4c3d81ea0eb5ebb076f3", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2023-06-01 22:50:34.303476", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"predict_fn": "predict", "loader_module": '
#                               '"mlflow.sklearn", "python_version": "3.9.16", '
#                               '"env": {"conda": "conda.yaml", "virtualenv": '
#                               '"python_env.yaml"}}, "sklearn": '
#                               '{"pickled_model": "model.pkl", '
#                               '"sklearn_version": "1.2.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"180751fe52a143638074f9fac06da798", '
#                               '"mlflow_version": "2.3.2", "signature": '
#                               '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                               '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                               '\\"shape\\": [-1, 6683]}}]", "outputs": '
#                               '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                               '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                               '[-1]}}]"}}]',
#   'mlflow.runName': 'dashing-horse-310',
#   'mlflow.source.git.commit': '981ccd4d024939198feffba2d5045fa595985d43',
#   'mlflow.source.name': 'register_model.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'mikygetyos'}>, info=<RunInfo: artifact_uri='/home/mikygetyos/Documents/My_Projects/NYC-Taxi-Duration/notebooks-exp-tracking/exp-tracking-homework/artifacts/2/918322b23a7d4c3d81ea0eb5ebb076f3/artifacts', end_time=1685659836704, experiment_id='2', lifecycle_stage='active', run_id='918322b23a7d4c3d81ea0eb5ebb076f3', run_name='dashing-horse-310', run_uuid='918322b23a7d4c3d81ea0eb5ebb076f3', start_time=1685659832839, status='FINISHED', user_id='mikygetyos'>>,
#  <Run: data=<RunData: metrics={'test_rmse': 2.2917830585394254,
#   'training_mean_absolute_error': 1.435279520419529,
#   'training_mean_squared_error': 3.87282522778403,
#   'training_r2_score': 0.27424625289133564,
#   'training_root_mean_squared_error': 1.967949498280896,
#   'training_score': 0.27424625289133564,
#   'val_rmse': 2.4516421799356767}, params={'bootstrap': 'True',
#   'ccp_alpha': '0.0',
#   'criterion': 'squared_error',
#   'max_depth': '16',
#   'max_features': '1.0',
#   'max_leaf_nodes': 'None',
#   'max_samples': 'None',
#   'min_impurity_decrease': '0.0',
#   'min_samples_leaf': '3',
#   'min_samples_split': '3',
#   'min_weight_fraction_leaf': '0.0',
#   'n_estimators': '28',
#   'n_jobs': '-1',
#   'oob_score': 'False',
#   'random_state': '42',
#   'verbose': '0',
#   'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#   'estimator_name': 'RandomForestRegressor',
#   'mlflow.log-model.history': '[{"run_id": "e70370c4b9e54f618312987ec52c3085", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2023-06-01 22:50:30.039769", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"predict_fn": "predict", "loader_module": '
#                               '"mlflow.sklearn", "python_version": "3.9.16", '
#                               '"env": {"conda": "conda.yaml", "virtualenv": '
#                               '"python_env.yaml"}}, "sklearn": '
#                               '{"pickled_model": "model.pkl", '
#                               '"sklearn_version": "1.2.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"cbf65637ae9c4a9ab3c22072f417847b", '
#                               '"mlflow_version": "2.3.2", "signature": '
#                               '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                               '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                               '\\"shape\\": [-1, 6683]}}]", "outputs": '
#                               '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                               '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                               '[-1]}}]"}}]',
#   'mlflow.runName': 'intelligent-pug-64',
#   'mlflow.source.git.commit': '981ccd4d024939198feffba2d5045fa595985d43',
#   'mlflow.source.name': 'register_model.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'mikygetyos'}>, info=<RunInfo: artifact_uri='/home/mikygetyos/Documents/My_Projects/NYC-Taxi-Duration/notebooks-exp-tracking/exp-tracking-homework/artifacts/2/e70370c4b9e54f618312987ec52c3085/artifacts', end_time=1685659832701, experiment_id='2', lifecycle_stage='active', run_id='e70370c4b9e54f618312987ec52c3085', run_name='intelligent-pug-64', run_uuid='e70370c4b9e54f618312987ec52c3085', start_time=1685659826948, status='FINISHED', user_id='mikygetyos'>>,
#  <Run: data=<RunData: metrics={'test_rmse': 2.294745868566162,
#   'training_mean_absolute_error': 1.4153979010204492,
#   'training_mean_squared_error': 3.790334257864697,
#   'training_r2_score': 0.28970476883263974,
#   'training_root_mean_squared_error': 1.9468780798665068,
#   'training_score': 0.28970476883263974,
#   'val_rmse': 2.451379690825458}, params={'bootstrap': 'True',
#   'ccp_alpha': '0.0',
#   'criterion': 'squared_error',
#   'max_depth': '20',
#   'max_features': '1.0',
#   'max_leaf_nodes': 'None',
#   'max_samples': 'None',
#   'min_impurity_decrease': '0.0',
#   'min_samples_leaf': '3',
#   'min_samples_split': '8',
#   'min_weight_fraction_leaf': '0.0',
#   'n_estimators': '25',
#   'n_jobs': '-1',
#   'oob_score': 'False',
#   'random_state': '42',
#   'verbose': '0',
#   'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#   'estimator_name': 'RandomForestRegressor',
#   'mlflow.log-model.history': '[{"run_id": "b68da596288244e78b48c842c8514dd1", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2023-06-01 22:50:23.949852", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"predict_fn": "predict", "loader_module": '
#                               '"mlflow.sklearn", "python_version": "3.9.16", '
#                               '"env": {"conda": "conda.yaml", "virtualenv": '
#                               '"python_env.yaml"}}, "sklearn": '
#                               '{"pickled_model": "model.pkl", '
#                               '"sklearn_version": "1.2.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"020ee5a5621a4d97b6795a98ba27fe6f", '
#                               '"mlflow_version": "2.3.2", "signature": '
#                               '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                               '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                               '\\"shape\\": [-1, 6683]}}]", "outputs": '
#                               '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                               '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                               '[-1]}}]"}}]',
#   'mlflow.runName': 'abrasive-fawn-75',
#   'mlflow.source.git.commit': '981ccd4d024939198feffba2d5045fa595985d43',
#   'mlflow.source.name': 'register_model.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'mikygetyos'}>, info=<RunInfo: artifact_uri='/home/mikygetyos/Documents/My_Projects/NYC-Taxi-Duration/notebooks-exp-tracking/exp-tracking-homework/artifacts/2/b68da596288244e78b48c842c8514dd1/artifacts', end_time=1685659826773, experiment_id='2', lifecycle_stage='active', run_id='b68da596288244e78b48c842c8514dd1', run_name='abrasive-fawn-75', run_uuid='b68da596288244e78b48c842c8514dd1', start_time=1685659820655, status='FINISHED', user_id='mikygetyos'>>,
#  <Run: data=<RunData: metrics={'test_rmse': 2.2854691906481364,
#   'training_mean_absolute_error': 1.4410764513945242,
#   'training_mean_squared_error': 3.948112551107436,
#   'training_r2_score': 0.26013767483835504,
#   'training_root_mean_squared_error': 1.9869857953964936,
#   'training_score': 0.26013767483835504,
#   'val_rmse': 2.449827329704216}, params={'bootstrap': 'True',
#   'ccp_alpha': '0.0',
#   'criterion': 'squared_error',
#   'max_depth': '15',
#   'max_features': '1.0',
#   'max_leaf_nodes': 'None',
#   'max_samples': 'None',
#   'min_impurity_decrease': '0.0',
#   'min_samples_leaf': '4',
#   'min_samples_split': '2',
#   'min_weight_fraction_leaf': '0.0',
#   'n_estimators': '34',
#   'n_jobs': '-1',
#   'oob_score': 'False',
#   'random_state': '42',
#   'verbose': '0',
#   'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#   'estimator_name': 'RandomForestRegressor',
#   'mlflow.log-model.history': '[{"run_id": "971a15c8976045dcab567108fabba734", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2023-06-01 22:50:15.393157", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"predict_fn": "predict", "loader_module": '
#                               '"mlflow.sklearn", "python_version": "3.9.16", '
#                               '"env": {"conda": "conda.yaml", "virtualenv": '
#                               '"python_env.yaml"}}, "sklearn": '
#                               '{"pickled_model": "model.pkl", '
#                               '"sklearn_version": "1.2.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"79ca10d0f0c54a82a563e858abcc51a8", '
#                               '"mlflow_version": "2.3.2", "signature": '
#                               '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                               '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                               '\\"shape\\": [-1, 6683]}}]", "outputs": '
#                               '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                               '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                               '[-1]}}]"}}]',
#   'mlflow.runName': 'carefree-goose-850',
#   'mlflow.source.git.commit': '981ccd4d024939198feffba2d5045fa595985d43',
#   'mlflow.source.name': 'register_model.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'mikygetyos'}>, info=<RunInfo: artifact_uri='/home/mikygetyos/Documents/My_Projects/NYC-Taxi-Duration/notebooks-exp-tracking/exp-tracking-homework/artifacts/2/971a15c8976045dcab567108fabba734/artifacts', end_time=1685659820390, experiment_id='2', lifecycle_stage='active', run_id='971a15c8976045dcab567108fabba734', run_name='carefree-goose-850', run_uuid='971a15c8976045dcab567108fabba734', start_time=1685659812190, status='FINISHED', user_id='mikygetyos'>>]

# %%
for run in runs:
    print(f"TEST_RMSE: {run.data.metrics['test_rmse']}")
# Out:
# TEST_RMSE: 2.2913864757421787
# TEST_RMSE: 2.2989550579001428
# TEST_RMSE: 2.2917830585394254
# TEST_RMSE: 2.294745868566162
# TEST_RMSE: 2.2854691906481364

# %%
experiment = client.get_experiment_by_name(HPO_EXPERIMENT_NAME)

# %%
best_run
# Out:
# <Run: data=<RunData: metrics={'test_rmse': 2.2913864757421787,
#  'training_mean_absolute_error': 1.4208732651603648,
#  'training_mean_squared_error': 3.8865885851691204,
#  'training_r2_score': 0.27166704840687694,
#  'training_root_mean_squared_error': 1.9714432746516244,
#  'training_score': 0.27166704840687694,
#  'val_rmse': 2.455971238567075}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '19',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '10',
#  'min_weight_fraction_leaf': '0.0',
#  'n_estimators': '12',
#  'n_jobs': '-1',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "372919df12db44a3a6f9612f9f2d96b6", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2023-06-01 22:50:38.475710", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.16", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.2.2", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"6f9a8db453604eb09f79450f4d2cfd3f", '
#                              '"mlflow_version": "2.3.2", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 6683]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]"}}]',
#  'mlflow.runName': 'victorious-whale-302',
#  'mlflow.source.git.commit': '981ccd4d024939198feffba2d5045fa595985d43',
#  'mlflow.source.name': 'register_model.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'mikygetyos'}>, info=<RunInfo: artifact_uri='/home/mikygetyos/Documents/My_Projects/NYC-Taxi-Duration/notebooks-exp-tracking/exp-tracking-homework/artifacts/2/372919df12db44a3a6f9612f9f2d96b6/artifacts', end_time=1685659840869, experiment_id='2', lifecycle_stage='active', run_id='372919df12db44a3a6f9612f9f2d96b6', run_name='victorious-whale-302', run_uuid='372919df12db44a3a6f9612f9f2d96b6', start_time=1685659836848, status='FINISHED', user_id='mikygetyos'>>
